# %% [markdown]
# <a href="https://colab.research.google.com/github/gewasaad/Data-Science-Basics/blob/main/week_13_homework_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.How do you load the House Prices dataset into a Pandas DataFrame?
import pandas as pd
df=pd.read_csv('/content/train_kaggle_housing.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
# 2. Write a code to display the first 10 rows of the dataset.
df.head(10)
df. iloc [0:10]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7         Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 8         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 9         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
# 6      8   2007        WD         Normal     307000
# 7     11   2009        WD         Normal     200000
# 8      4   2008        WD        Abnorml     129900
# 9      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]

# %%
# 3.How can you check for missing values in the dataset?

df. isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
# 4.Write a Python script to calculate the mean, median, and standard deviation of 'SalePrice'.
df['SalePrice']. mean()
# Out:
# 180921.19589041095

# %%
df['SalePrice']. median()
# Out:
# 163000.0

# %%
df['SalePrice']. std()
# Out:
# 79442.50288288662

# %%
df['SalePrice']. sum()
# Out:
# 264144946

# %%
#5. Create a histogram of the 'LotArea' feature.

import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(df['LotArea'])
# Out:
# <Axes: xlabel='LotArea', ylabel='Count'>

# %%
#6. How do you generate a box plot for the 'YearBuilt' feature using Seaborn?

sns.boxplot(x=df['YearBuilt'])
# Out:
# <Axes: xlabel='YearBuilt'>

# %%
# 7.Write a code to list all column names in the dataset.
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
# 8.How can you filter out houses with 'SalePrice' above $300,000?
df[df['SalePrice']>300000]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 20      21          60       RL        101.0    14215   Pave   NaN      IR1
# 27      28          20       RL         98.0    11478   Pave   NaN      Reg
# 35      36          60       RL        108.0    13418   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1373  1374          20       RL          NaN    11400   Pave   NaN      Reg
# 1388  1389          20       RL         42.0    14892   Pave   NaN      IR1
# 1417  1418          60       RL          NaN    16545   Pave   NaN      IR1
# 1437  1438          20       RL         96.0    12444   Pave   NaN      Reg
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 6            Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 11           Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 20           Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 27           Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 35           Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# ...          ...       ...  ...      ...    ...   ...         ...     ...
# 1373         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1388         HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 1417         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1437         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1442         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 6         8   2007        WD         Normal     307000
# 11        7   2006       New        Partial     345000
# 20       11   2006       New        Partial     325300
# 27        5   2010        WD         Normal     306000
# 35        9   2006        WD         Normal     309000
# ...     ...    ...       ...            ...        ...
# 1373      3   2007        WD         Normal     466500
# 1388     10   2009        WD         Normal     377500
# 1417      5   2009        WD         Normal     340000
# 1437     11   2008       New        Partial     394617
# 1442      4   2009        WD         Normal     310000
#
# [115 rows x 81 columns]

# %%
df['OverallQual']
# Out:
# 0       7
# 1       6
# 2       7
# 3       7
# 4       8
#        ..
# 1455    6
# 1456    6
# 1457    7
# 1458    5
# 1459    5
# Name: OverallQual, Length: 1460, dtype: int64

# %%
# 9.Create a bar plot showing the count of houses for each 'OverallQual' rating.
sns.countplot(x=df['OverallQual'])
# Out:
# <Axes: xlabel='OverallQual', ylabel='count'>

# %%
# 10.Write a Python script to display summary statistics for all numerical features.

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
# 11. Analyze the distribution of 'SalePrice' and identify its skewness.
sns.histplot(df['SalePrice'], kde=True, color='green')
df['SalePrice'].skew()
#possitive skew
# Out:
# 1.8828757597682129

# %%
df['SalePrice'].mode()
# Out:
# 0    140000
# Name: SalePrice, dtype: int64

# %%
median=df['SalePrice'].iloc [731]
print (median)
# Out:
# 187500

# %%
df['SalePrice'].median()
# Out:
# 163000.0

# %%
df[df['SalePrice']==163000.0]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 173    174          20       RL         80.0    10197   Pave   NaN      IR1
# 735    736          75       RM         60.0    10800   Pave   NaN      Reg
# 1171  1172          20       RL         76.0     9120   Pave   NaN      Reg
# 1393  1394         190       RM         60.0    10800   Pave  Pave      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 173          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 735          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1171         Lvl    AllPub  ...        0    NaN   NaN        Shed    1400
# 1393         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 173       6   2008       COD         Normal     163000
# 735      10   2006        WD         Normal     163000
# 1171     11   2008        WD         Normal     163000
# 1393      4   2008        WD         Normal     163000
#
# [4 rows x 81 columns]

# %%
# 12.Explore the relationship between 'TotalBsmtSF' and 'SalePrice' using a scatter plot. What insights can you gather?
# %matplotlib inline
ax=df.plot(kind='scatter', x='TotalBsmtSF',y='SalePrice', c='blue', marker='o', alpha= 0.5)

# %%
sns.scatterplot(x='TotalBsmtSF',y='SalePrice',c='pink',s=10,data=df)
# Out:
# <Axes: xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %%
#13. Investigate the impact of 'YearBuilt' on 'SalePrice' - does newer mean pricier?
sns.scatterplot(x='YearBuilt',y='SalePrice',c='red',s=10,data=df)
# Out:
# <Axes: xlabel='YearBuilt', ylabel='SalePrice'>

# %%
#14. Perform a groupby operation to find the average 'SalePrice' per 'Neighborhood'.
df.groupby('Neighborhood')['SalePrice'].mean()
# Out:
# Neighborhood
# Blmngtn    194870.882353
# Blueste    137500.000000
# BrDale     104493.750000
# BrkSide    124834.051724
# ClearCr    212565.428571
# CollgCr    197965.773333
# Crawfor    210624.725490
# Edwards    128219.700000
# Gilbert    192854.506329
# IDOTRR     100123.783784
# MeadowV     98576.470588
# Mitchel    156270.122449
# NAmes      145847.080000
# NPkVill    142694.444444
# NWAmes     189050.068493
# NoRidge    335295.317073
# NridgHt    316270.623377
# OldTown    128225.300885
# SWISU      142591.360000
# Sawyer     136793.135135
# SawyerW    186555.796610
# Somerst    225379.837209
# StoneBr    310499.000000
# Timber     242247.447368
# Veenker    238772.727273
# Name: SalePrice, dtype: float64

# %%
#15.Create a correlation matrix for numerical features. Which features are most correlated with 'SalePrice'?
import matplotlib.pyplot as plt
from sklearn. datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split

# %%
correlation_matrix = df[['SalePrice','YearBuilt','MSSubClass','LotFrontage','LotArea','PoolArea','MiscVal','MoSold','YrSold']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df['SalePrice'].skew()

# %%
#16. Compare the distribution of 'SalePrice' between houses with and without central air conditioning.
sns.kdeplot(df[df['CentralAir'] == 'Y']['SalePrice'], shade= True, label='With AC')
sns.kdeplot(df[df['CentralAir'] == 'N']['SalePrice'], shade=True, label='Without AC')

plt.title('Density Plot of SalePrice for Houses With and Without AC')
plt.xlabel('SalePrice')
plt.legend()
plt.show()
# Out:
# <ipython-input-56-403eacc1cc07>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df['CentralAir'] == 'Y']['SalePrice'], shade= True, label='With AC')
# <ipython-input-56-403eacc1cc07>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df['CentralAir'] == 'N']['SalePrice'], shade=True, label='Without AC')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df['CentralAir'] contains 'Y' for Yes and 'N' for No
sns.boxplot(x='CentralAir', y='SalePrice', data=df)
plt.title('Distribution of SalePrice by Central Air Conditioning')
plt.show()

# %%
#17.Analyze if there is a significant difference in 'SalePrice' based on 'GarageType'.
sns.violinplot(x='GarageType', y='SalePrice', data=df)
plt.title('SalePrice Distribution by Garage Type')
plt.show()

# %%
#18.Investigate the effect of 'LotFrontage' on 'SalePrice'. Is there a trend?
sns.regplot(x='LotFrontage', y='SalePrice', data=df)
plt.title('SalePrice Distribution by LotFrontage')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression()


df['LotFrontage']=df['LotFrontage'].fillna(0)
model.fit(df[['LotFrontage']],df['SalePrice'])
df['y predicted']=model.predict(df[['LotFrontage']])

ax=sns.scatterplot(x='LotFrontage',y='SalePrice',data=df,color='red')
sns.scatterplot(x='LotFrontage',y='y predicted',data=df,color='green',ax=ax)
# Out:
# <Axes: xlabel='LotFrontage', ylabel='SalePrice'>

# %%
#19.Use a box plot to compare the 'SalePrice' distribution across different 'HouseStyle'.
sns.boxplot(x='HouseStyle', y='SalePrice', data=df)
plt.title('Distribution across different HouseStyle')
plt.show()

# %%
#20.Explore how 'OverallCond' affects the 'SalePrice'. Is better condition always associated with higher prices?
sns.barplot(x='OverallCond', y='SalePrice', data=df)
plt.title('SalePrice Distribution by OverallCond')
plt.show()

# %%
#21. What features strongly influence the 'SalePrice'? Justify with statistical evidence.
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-83-f42399076dd4>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm')

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice', 'AC', 'y predicted'],
#       dtype='object')

# %%
numerical_features = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
feature=['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
       'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
       'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
       'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
       'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
       'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
       'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
       'SaleCondition']
for feature in numerical_features:
    if feature != 'SalePrice':
        df.plot(kind='scatter', x=feature, y='SalePrice')
        plt.title(f'SalePrice vs {feature}')
        plt.show()

# %%
#22.Is there a pattern between the number of bedrooms ('BedroomAbvGr') and the sale price? Analyze and interpret.
#23.Identify outliers in 'GrLivArea' and discuss how they might affect the model.
#24.Explore the possibility of new feature creation. For instance, combine 'TotalBsmtSF' and '1stFlrSF' into a new feature and analyze its impact.
#25.Discuss the potential effect of multicollinearity in the dataset.
#26.Evaluate the relationship between 'SalePrice' and categorical variables like 'MSZoning'. How can these insights guide feature engineering?
#27.Predict if a house has a 'FireplaceQu' based on its 'SalePrice'. What patterns do you observe?
#28.Investigate how seasonal factors (like month of sale) impact 'SalePrice'.
#29.Can 'BsmtQual' and 'BsmtCond' be combined into a single feature for a more effective analysis? Provide statistical reasoning.
#30.Explore the effect of remodeling ('YearRemodAdd') on 'SalePrice'. Does recent remodeling significantly increase the house value?
